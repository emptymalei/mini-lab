# %%
import numpy as np

# %% [markdown]
# ## Sin Function

# %%
def sin_data(x):
    res = np.sin(x)
    return res

# %%
X = [[i] for i in range(1000)]

# %%
sin_data(X)
# Out:
# array([[ 0.00000000e+00],
#        [ 8.41470985e-01],
#        [ 9.09297427e-01],
#        [ 1.41120008e-01],
#        [-7.56802495e-01],
#        [-9.58924275e-01],
#        [-2.79415498e-01],
#        [ 6.56986599e-01],
#        [ 9.89358247e-01],
#        [ 4.12118485e-01],
#        [-5.44021111e-01],
#        [-9.99990207e-01],
#        [-5.36572918e-01],
#        [ 4.20167037e-01],
#        [ 9.90607356e-01],
#        [ 6.50287840e-01],
#        [-2.87903317e-01],
#        [-9.61397492e-01],
#        [-7.50987247e-01],
#        [ 1.49877210e-01],
#        [ 9.12945251e-01],
#        [ 8.36655639e-01],
#        [-8.85130929e-03],
#        [-8.46220404e-01],
#        [-9.05578362e-01],
#        [-1.32351750e-01],
#        [ 7.62558450e-01],
#        [ 9.56375928e-01],
#        [ 2.70905788e-01],
#        [-6.63633884e-01],
#        [-9.88031624e-01],
#        [-4.04037645e-01],
#        [ 5.51426681e-01],
#        [ 9.99911860e-01],
#        [ 5.29082686e-01],
# ...
