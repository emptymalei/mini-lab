# %% [markdown]
# ## Skewness

# %% [markdown]
# ### Locations

# %% [markdown]
# Compare the locations in different distributions.

# %%
from scipy.stats import uniform

# %%
x =

# %%
uniform().pdf()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-8c1dfc86c3ad> in <module>
# ----> 1 uniform().pdf()
#
# TypeError: pdf() missing 1 required positional argument: 'x'

# %%
import os

# %%
os.listdir("/tmp")
# Out:
# ['com.apple.launchd.oQu8j1n5Hj',
#  'com.google.Keystone',
#  '.ICE-unix',
#  'powerlog',
#  'MathLink',
#  'com.apple.launchd.AyQgol2QIO',
#  'com.apple.launchd.4NA5ebpJXr',
#  '.X11-unix',
#  'post_to_slack_kitchen',
#  'mongodb-27017.sock',
#  '.dbfseventsd',
#  '.font-unix']

# %%
import datetime

# %%
datetime.datetime(2020,3,4,11,23,0).date().isoformat()
# Out:
# '2020-03-04'

# %%
datetime.datetime(2020,3,4,11,23,0).minute
# Out:
# 23

# %%
f"{datetime.datetime(2020,3,4,11,3,0).minute:02.0f}"
# Out:
# '03'

# %%
import html

# %%
test= "Nieder&ouml;sterreich"

# %%
html.unescape(test)
# Out:
# 'Niederösterreich'

# %%
import pandas as pd

# %%
"http://docs.google.com/spreadsheets/d/1itaohdPiAeniCXNlntNztZ_oRvjh0HsGuJXUJWET008/gviz/tq?tqx=out:csv"
# Out:
# 'http://docs.google.com/spreadsheets/d/1itaohdPiAeniCXNlntNztZ_oRvjh0HsGuJXUJWET008/gviz/tq?tqx=out:csv'

# %%
from pdfrw import PdfReader

# %%
x = PdfReader('/Users/leima/Downloads/C_17_pagineAree_5351_1_file.pdf')

# %%
x
# Out:
# {'/Info': {'/Author': '(wtaddei)',
#   '/CreationDate': "(D:20200305171006+01'00')",
#   '/ModDate': "(D:20200305171006+01'00')",
#   '/Producer': '(Microsoft: Print To PDF)',
#   '/Title': '(Monitoraggio 5 marzo.xlsx)'},
#  '/Root': {'/Pages': {'/Count': '3',
#    '/Kids': [{'/Contents': [{'/Filter': '/FlateDecode', '/Length': '3966'}],
#      '/CropBox': ['0.0', '0.0', '595.32001', '841.92004'],
#      '/MediaBox': ['0.0', '0.0', '595.32001', '841.92004'],
#      '/Parent': {...},
#      '/Resources': {'/Font': {'/F1': {'/BaseFont': '/CIDFont+F1',
#         '/DescendantFonts': [{'/BaseFont': '/CIDFont+F1',
#           '/CIDSystemInfo': {'/Ordering': '(Identity)',
#            '/Registry': '(Adobe)',
#            '/Supplement': '0'},
#           '/CIDToGIDMap': '/Identity',
#           '/FontDescriptor': {'/Ascent': '952',
#            '/CapHeight': '631',
#            '/Descent': '-268',
#            '/Flags': '6',
#            '/FontBBox': ['-854', '-268', '854', '952'],
# ...
